# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
df = pd.read_csv('1954221.csv')
df
# Out:
#          STATION                 NAME     DATE  AWND   CDSD   CLDD  DP01  \
# 0    USC00200228  ANN ARBOR SE, MI US  2003-04   NaN    NaN    NaN   4.0
# 1    USC00200228  ANN ARBOR SE, MI US  2003-05   NaN    NaN    1.7  20.0
# 2    USC00200228  ANN ARBOR SE, MI US  2003-06   NaN    NaN   35.8  12.0
# 3    USC00200228  ANN ARBOR SE, MI US  2003-07   NaN    NaN   90.2  10.0
# 4    USC00200228  ANN ARBOR SE, MI US  2003-08   NaN    NaN   90.8  13.0
# 5    USC00200228  ANN ARBOR SE, MI US  2003-09   NaN    NaN   13.0  14.0
# 6    USC00200228  ANN ARBOR SE, MI US  2003-10   NaN    NaN    0.0  10.0
# 7    USC00200228  ANN ARBOR SE, MI US  2003-11   NaN    NaN    0.0  16.0
# 8    USC00200228  ANN ARBOR SE, MI US  2003-12   NaN    NaN    0.0  17.0
# 9    USC00200228  ANN ARBOR SE, MI US  2004-01   NaN    0.0    0.0  17.0
# 10   USC00200228  ANN ARBOR SE, MI US  2004-02   NaN    0.0    0.0   7.0
# 11   USC00200228  ANN ARBOR SE, MI US  2004-03   NaN    0.0    0.0  24.0
# ...

# %%
df['NAME'].unique()
# Out:
# array(['ANN ARBOR SE, MI US', 'SALINE 4 SW, MI US',
#        'DETROIT WILLOW RUN AIRPORT, MI US', 'MILAN WWTP, MI US',
#        'ANN ARBOR U OF MICH, MI US', 'SALINE WWTP, MI US',
#        'CANTON, MI US', 'ANN ARBOR MUNICIPAL AIRPORT, MI US',
#        'CHELSEA, MI US'], dtype=object)

# %%
df1=df.drop(columns='STATION')
df2=df1.drop(columns='NAME')
df2
# Out:
#         DATE  AWND   CDSD   CLDD  DP01  DP10  DSND  DSNW  DT00  DT32  ...  \
# 0    2003-04   NaN    NaN    NaN   4.0   2.0   0.0   0.0   NaN   NaN  ...
# 1    2003-05   NaN    NaN    1.7  20.0  12.0   0.0   0.0   0.0   1.0  ...
# 2    2003-06   NaN    NaN   35.8  12.0   7.0   0.0   0.0   0.0   0.0  ...
# 3    2003-07   NaN    NaN   90.2  10.0   6.0   0.0   0.0   0.0   0.0  ...
# 4    2003-08   NaN    NaN   90.8  13.0  10.0   0.0   0.0   0.0   0.0  ...
# 5    2003-09   NaN    NaN   13.0  14.0   7.0   0.0   0.0   0.0   0.0  ...
# 6    2003-10   NaN    NaN    0.0  10.0   4.0   0.0   0.0   0.0   9.0  ...
# 7    2003-11   NaN    NaN    0.0  16.0   9.0   1.0   1.0   0.0  14.0  ...
# 8    2003-12   NaN    NaN    0.0  17.0   6.0   9.0   3.0   0.0  28.0  ...
# 9    2004-01   NaN    0.0    0.0  17.0   7.0  27.0   6.0   8.0  30.0  ...
# 10   2004-02   NaN    0.0    0.0   7.0   3.0  26.0   2.0   2.0  29.0  ...
# 11   2004-03   NaN    0.0    0.0  24.0  11.0   6.0   3.0   0.0  19.0  ...
# ...

# %%
df.sort_values(by=['DATE'])
# Out:
#          STATION                                NAME     DATE  AWND   CDSD  \
# 505  USC00201502                      CHELSEA, MI US  1990-01   NaN    NaN
# 180  USC00200230          ANN ARBOR U OF MICH, MI US  1990-01   NaN    0.0
# 181  USC00200230          ANN ARBOR U OF MICH, MI US  1990-02   NaN    0.0
# 506  USC00201502                      CHELSEA, MI US  1990-02   NaN    NaN
# 182  USC00200230          ANN ARBOR U OF MICH, MI US  1990-03   NaN    1.1
# 507  USC00201502                      CHELSEA, MI US  1990-03   NaN    NaN
# 183  USC00200230          ANN ARBOR U OF MICH, MI US  1990-04   NaN   21.9
# 508  USC00201502                      CHELSEA, MI US  1990-04   NaN    NaN
# 184  USC00200230          ANN ARBOR U OF MICH, MI US  1990-05   NaN   24.7
# 509  USC00201502                      CHELSEA, MI US  1990-05   NaN    NaN
# 510  USC00201502                      CHELSEA, MI US  1990-06   NaN    NaN
# ...

# %% [markdown]
# There are a different number of stations that have the average values for each month for each region. I am going to take the average of each month of all stations to arrive at an average value for the whole city of Ann Arbor for that month. Then I will have a dataframe that consists only of the average values of everything for the total number of months between 1990 and 2005.

# %% [markdown]
# Before that, I need to come up with a way of handling missing values.

# %%
for df['DATE'] in df['DATE'].unique():
    df
